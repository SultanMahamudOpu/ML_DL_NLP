# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification, make_moons, make_circles, load_breast_cancer, load_diabetes
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC, SVR
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, mean_squared_error, r2_score

np.random.seed(42)
plt.rcParams['figure.figsize']=(6, 4)

# %%
# helper function to plot decision boundary for 2D data
def plot_decision_boundary(model, X, y, title='Decesion boundary'):
    x_min, x_max= X[:, 0].min()- 1, X[:, 0].max()+ 1
    y_min, y_max= X[:, 1].min()- 1, X[:, 1].max()+ 1
    xx, yy =np.meshgrid(
        np.linspace(x_min, x_max, 300),
        np.linspace(y_min, y_max, 300)
    )
    grid= np.c_[xx.ravel(), yy.ravel()]
    Z= model.predict(grid)
    Z= Z.reshape(xx.shape)

    plt.contourf(xx, yy, Z, alpha=0.2, cmap='bwr')
    plt.scatter(X[:, 0], X[:, 1], c=y, cmap='bwr', edgecolors='k', alpha=0.8)
    plt.title(title)
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()

# %%
# moons dataset
X_moon, y_moon= make_moons(
    n_samples= 300,
    noise= 0.25,
    random_state= 42
)

plt.scatter(X_moon[:, 0], X_moon[:, 1], c=y_moon, cmap='bwr', edgecolors='k', alpha=0.8)
plt.title('make moons dataset')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
# scale moons data
X_moon_train, X_moon_test, y_moon_train, y_moon_test= train_test_split(X_moon, y_moon, test_size=0.2, random_state=42)

scaler_moon= StandardScaler()
X_moon_train_scaled= scaler_moon.fit_transform(X_moon_train)
X_moon_test_scaled= scaler_moon.transform(X_moon_test)

# %%
# linear kernel on moons
svc_linear= SVC(kernel='linear', C=1.0, random_state=42)
svc_linear.fit(X_moon_train_scaled, y_moon_train)

plot_decision_boundary(svc_linear, X_moon_train_scaled, y_moon_train, title='Linear SVM on moons (training data)')

pred= svc_linear.predict(X_moon_test_scaled)
acc= accuracy_score(y_moon_test, pred)
print('Accuracy (linear kernel on moons): ',acc)
# Out:
# Accuracy (linear kernel on moons):  0.8833333333333333

# %%
# Polynomial kernel on moons
svc_poly= SVC(kernel='poly', degree=3, C=20.0, gamma='scale', random_state=42)
svc_poly.fit(X_moon_train_scaled, y_moon_train)

plot_decision_boundary(svc_poly, X_moon_train_scaled, y_moon_train, title='Polynomial kernel (degree 3) on moons')

pred= svc_poly.predict(X_moon_test_scaled)
acc= accuracy_score(y_moon_test, pred)
print('Accuracy (polynomial kernel on moons): ',acc)
# Out:
# Accuracy (polynomial kernel on moons):  0.9

# %%
# Polynomial kernel on moons
svc_poly= SVC(kernel='poly', degree=3, C=20.0, gamma='scale', random_state=42)
svc_poly.fit(X_moon_train_scaled, y_moon_train)

plot_decision_boundary(svc_poly, X_moon_train_scaled, y_moon_train, title='Polynomial kernel (degree 3) on moons')

pred= svc_poly.predict(X_moon_test_scaled)
acc= accuracy_score(y_moon_test, pred)
print('Accuracy (polynomial kernel on moons): ',acc)
# Out:
# Accuracy (polynomial kernel on moons):  0.9

# %%
# Polynomial kernel on moons
svc_poly= SVC(kernel='poly', degree=3, C=20.0, gamma='scale', random_state=42)
svc_poly.fit(X_moon_train_scaled, y_moon_train)

plot_decision_boundary(svc_poly, X_moon_train_scaled, y_moon_train, title='Polynomial kernel (degree 3) on moons')

pred= svc_poly.predict(X_moon_test_scaled)
acc= accuracy_score(y_moon_test, pred)
print('Accuracy (polynomial kernel on moons): ',acc)
# Out:
# Accuracy (polynomial kernel on moons):  0.9

# %%
# RBF kernel on moons
svc_rbf= SVC(kernel='rbf', C=10.0, gamma=1, random_state=42)
svc_rbf.fit(X_moon_train_scaled, y_moon_train)

plot_decision_boundary(svc_rbf, X_moon_train_scaled, y_moon_train, title='Accuracy (RBF kernel on moons)')

pred= svc_rbf.predict(X_moon_test_scaled)
acc= accuracy_score(y_moon_test, pred)
print('Accuracy (RBF kernel on moons): ',acc)
# Out:
# Accuracy (RBF kernel on moons):  0.9166666666666666
